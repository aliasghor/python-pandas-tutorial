# %% [markdown]
# # 29. Random sampling pada pandas `DataFrame`

# %% [markdown]
# ## Import module

# %%
import pandas as pd

pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## Persiapan `DataFrame`

# %%
data = {
    "col_1":[1,2,3,4,5],
    "col_2":[10,20,30,40,50]
}

df = pd.DataFrame(data)
df
# Out:
#    col_1  col_2
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %% [markdown]
# ## Random sampling with/without replacement

# %%
df.sample(n=4,replace=False,random_state=0)
# Out:
#    col_1  col_2
# 2      3     30
# 0      1     10
# 1      2     20
# 3      4     40

# %%
df.sample(n=4,replace=True,random_state=0)
# Out:
#    col_1  col_2
# 4      5     50
# 0      1     10
# 3      4     40
# 3      4     40
