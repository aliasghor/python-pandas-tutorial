# %% [markdown]
# # 44. Menata ulang penempatan kolom `DataFrame`

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Persiapan `DataFrame`

# %%
n_rows = 5
n_cols = 5
cols = list("ABCDE")

df = pd.DataFrame(np.random.randint(1,10,size=(n_rows,n_cols)),columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  9  4  6  4  9
# 1  1  4  5  9  8
# 2  4  3  4  7  2
# 3  5  6  5  9  5
# 4  8  4  4  1  9

# %% [markdown]
# # Menata ulang penempatan kolom pada `DataFrame`

# %%
df[["D","C","A","E","B"]]
# Out:
#    D  C  A  E  B
# 0  4  6  9  9  4
# 1  9  5  1  8  4
# 2  7  4  4  2  3
# 3  9  5  5  5  6
# 4  1  4  8  9  4

# %%
df
# Out:
#    A  B  C  D  E
# 0  9  4  6  4  9
# 1  1  4  5  9  8
# 2  4  3  4  7  2
# 3  5  6  5  9  5
# 4  8  4  4  1  9

# %%
df = df[["D","C","A","E","B"]]
df
# Out:
#    D  C  A  E  B
# 0  4  6  9  9  4
# 1  9  5  1  8  4
# 2  7  4  4  2  3
# 3  9  5  5  5  6
# 4  1  4  8  9  4
