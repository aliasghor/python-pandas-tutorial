# %% [markdown]
# # 26. Membuat Data Frame dari hasil seleksi Spreadsheet

# %% [markdown]
# ## Import module

# %%
import pandas as pd

# %% [markdown]
# ## Membuat `DataFrame` dari hasil seleksi (clipboard) Google SpreadSheet

# %%
df = pd.read_clipboard()
df
# Out:
#                                    Unnamed: 3
# PH  ket DAFTAR TUGAS                    nilai
# PH1 b1  penjumlahan bilangan bulat        100
#     b2  pengurangan bilangan bulat         20
# PH2 p1  penjumlahan pecahan 1 - 5          38
#     p2  pengurangan pecahan 6 - 10        NaN
#     p3  perkalian pecahan 11 - 14         NaN
#     p4  pembagian pecahan 15 - 18         NaN
# PH3 h1  soal himpunan                     NaN
# NaN NaN PTS                                28
