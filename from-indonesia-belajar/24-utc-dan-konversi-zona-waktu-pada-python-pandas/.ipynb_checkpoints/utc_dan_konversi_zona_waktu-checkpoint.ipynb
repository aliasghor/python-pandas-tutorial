# %% [markdown]
# # 24. UTC dan konversi zona waktu (time zone) pada Python Pandas

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# ## Persiapan `Series`
