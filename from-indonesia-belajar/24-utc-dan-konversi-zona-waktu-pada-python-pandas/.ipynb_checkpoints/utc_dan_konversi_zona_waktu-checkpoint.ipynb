# %% [markdown]
# # 24. UTC dan konversi zona waktu (time zone) pada Python Pandas

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# ## Persiapan `Series`

# %%
s = pd.Series(np.arange(1054875600,1720605441,1800))
s = pd.to_datetime(s,unit='s')
s.head()
# Out:
# 0   2003-06-06 05:00:00
# 1   2003-06-06 05:30:00
# 2   2003-06-06 06:00:00
# 3   2003-06-06 06:30:00
# 4   2003-06-06 07:00:00
# dtype: datetime64[ns]

# %% [markdown]
# ## Pengaturan zona waktu (time zone)

# %%
s = s.dt.tz_localize('UTC')
s.head()
# Out:
# 0   2003-06-06 05:00:00+00:00
# 1   2003-06-06 05:30:00+00:00
# 2   2003-06-06 06:00:00+00:00
# 3   2003-06-06 06:30:00+00:00
# 4   2003-06-06 07:00:00+00:00
# dtype: datetime64[ns, UTC]

# %%
s = s.dt.tz_convert('Asia/Jakarta')
s.head()
# Out:
# 0   2003-06-06 12:00:00+07:00
# 1   2003-06-06 12:30:00+07:00
# 2   2003-06-06 13:00:00+07:00
# 3   2003-06-06 13:30:00+07:00
# 4   2003-06-06 14:00:00+07:00
# dtype: datetime64[ns, Asia/Jakarta]

# %%
s = s.dt.tz_convert('Australia/Hobart')
s.head()
# Out:
# 0   2003-06-06 15:00:00+10:00
# 1   2003-06-06 15:30:00+10:00
# 2   2003-06-06 16:00:00+10:00
# 3   2003-06-06 16:30:00+10:00
# 4   2003-06-06 17:00:00+10:00
# dtype: datetime64[ns, Australia/Hobart]
