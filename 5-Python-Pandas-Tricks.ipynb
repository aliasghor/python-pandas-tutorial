# %% [markdown]
# # 5. Membalik urutan baris dan kolom pada `DataFrame`

# %%
# Import all of the necessary packages
import pandas as pd
import numpy as np

# %% [markdown]
# ## Persiapan `DataFrame`

# %%
n_rows = 5
n_cols = 5
cols = list("ABCDE")

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  8  6  6  1  2
# 1  6  8  6  9  2
# 2  1  8  6  2  3
# 3  6  5  1  5  9
# 4  3  6  9  6  3

# %% [markdown]
# ## Membalik urutan kolom

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  2  1  6  6  8
# 1  2  9  6  8  6
# 2  3  2  6  8  1
# 3  9  5  1  5  6
# 4  3  6  9  6  3

# %% [markdown]
# ## Membalik urutan baris

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  3  6  9  6  3
# 3  6  5  1  5  9
# 2  1  8  6  2  3
# 1  6  8  6  9  2
# 0  8  6  6  1  2

# %% [markdown]
# ## Membalik urutan baris, dan melakukan penyesuaian index

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  3  6  9  6  3
# 1  6  5  1  5  9
# 2  1  8  6  2  3
# 3  6  8  6  9  2
# 4  8  6  6  1  2
