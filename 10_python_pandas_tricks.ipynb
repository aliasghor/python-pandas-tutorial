# %% [markdown]
# # 10. Mengganti nama (label) pada kolom `DataFrame` berdasarkan pola

# %%
# Import the pandas package
import pandas as pd

# %% [markdown]
# ## Persiapan `DataFrame`

# %%
df = pd.read_csv("titanicfull.csv")
df.columns = ["Pclass", "Survival status", "full Name", "Sex   ", "   Age", "Sib SP", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]
df_backup = df.copy(deep=True)

df.head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    Sex        Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female   29.00       0      0   24160  211.3375       B5        S
# 1    male    0.92       1      2  113781  151.5500  C22 C26        S
# 2  female    2.00       1      2  113781  151.5500  C22 C26        S
# 3    male   30.00       1      2  113781  151.5500  C22 C26        S
# 4  female   25.00       1      2  113781  151.5500  C22 C26        S

# %%
df.columns
# Out:
# Index(['Pclass', 'Survival status', 'full Name', 'Sex   ', '   Age', 'Sib SP',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Survival status"] = df["Survival status"].astype("bool")
df_backup["Survival status"] = df["Survival status"].astype("bool")

# %% [markdown]
# ## Menggunakan lowercase untuk nama kolom, dan mengganti spasi dengan `_`

# %%
df.columns = df.columns.str.replace(" ", "_").str.lower()
df.head()
# Out:
#    pclass  survival_status                                        full_name  \
# 0       1             True                    Allen, Miss. Elisabeth Walton
# 1       1             True                   Allison, Master. Hudson Trevor
# 2       1            False                     Allison, Miss. Helen Loraine
# 3       1            False             Allison, Mr. Hudson Joshua Creighton
# 4       1            False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    sex___  ___age  sib_sp  parch  ticket      fare    cabin embarked
# 0  female   29.00       0      0   24160  211.3375       B5        S
# 1    male    0.92       1      2  113781  151.5500  C22 C26        S
# 2  female    2.00       1      2  113781  151.5500  C22 C26        S
# 3    male   30.00       1      2  113781  151.5500  C22 C26        S
# 4  female   25.00       1      2  113781  151.5500  C22 C26        S

# %%
df = df_backup
df.columns = df.columns.str.title().str.strip().str.replace(" ", "_")
df.head()
# Out:
#    Pclass  Survival_Status                                        Full_Name  \
# 0       1             True                    Allen, Miss. Elisabeth Walton
# 1       1             True                   Allison, Master. Hudson Trevor
# 2       1            False                     Allison, Miss. Helen Loraine
# 3       1            False             Allison, Mr. Hudson Joshua Creighton
# 4       1            False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       Sex    Age  Sib_Sp  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S
